# %% [markdown]
# ## 3.4 CartPoleをQ学習で制御

# %%
# 导入所需要的包
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import gym

# %%
# 声明动画的绘制函数
# 参考URL http://nbviewer.jupyter.org/github/patrickmineault
# /xcorr-notebooks/blob/master/Render%20OpenAI%20gym%20as%20GIF.ipynb
from JSAnimation.IPython_display import display_animation
from matplotlib import animation
from IPython.display import display


def display_frames_as_gif(frames):
    """
    Displays a list of frames as a gif, with controls
    """
    plt.figure(figsize=(frames[0].shape[1]/72.0, frames[0].shape[0]/72.0),
               dpi=72)
    patch = plt.imshow(frames[0])
    plt.axis('off')

    def animate(i):
        patch.set_data(frames[i])

    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames),
                                   interval=50)

    anim.save('movie_cartpole.mp4')  # 视频b
    display(display_animation(anim, default_mode='loop'))

# %%
# 参数的设定
ENV = 'CartPole-v0'  # 要使用的任务名称
NUM_DIZITIZED = 6  # 将每个状态划分为离散值的个数
GAMMA = 0.99  # 时间折扣率
ETA = 0.5  # 学习系数
MAX_STEPS = 200  # 一次试验中的步数
NUM_EPISODES = 1000  # 最大试验次数

# %% [markdown]
# ### Agent类接收初始化函数init中CartPole状态变量的数量和动作类型的数量，并生成Brain类作为自己的大脑。Agent类包括get_action和updata_Q_function这两个方法。

# %%
class Agent:
    '''CartPole的智能体类，它将是一个带有杆的小车'''

    def __init__(self, num_states, num_actions):
        self.brain = Brain(num_states, num_actions)  # 为智能体创建大脑以做出决定

    def update_Q_function(self, observation, action, reward, observation_next):
        '''Q函数的更新'''
        self.brain.update_Q_table(
            observation, action, reward, observation_next)

    def get_action(self, observation, step):
        '''动作的确定'''
        action = self.brain.decide_action(observation, step)
        return action

# %% [markdown]
# ### 定义Brain类，它是Agent的大脑。更新Q表与确定动作的方法。

# %%
class Brain:
    '''这是一个将成为智能体大脑的类，用于进行Q学习'''

    def __init__(self, num_states, num_actions):
        self.num_actions = num_actions  # CartPole有两种动作（向左或向右）

        # 创建Q表。行数是将状态转换为数字得到的分割数（有4各变量），列表示为动作数
        self.q_table = np.random.uniform(low=0, high=1, size=(
            NUM_DIZITIZED**num_states, num_actions))


    def bins(self, clip_min, clip_max, num):
        '''求得观察到的状态（连续值）到离散值的数字转换阈值'''
        return np.linspace(clip_min, clip_max, num + 1)[1:-1]

    def digitize_state(self, observation):
        '''将观察到的observation转换为离散的值'''
        cart_pos, cart_v, pole_angle, pole_v = observation
        digitized = [
            np.digitize(cart_pos, bins=self.bins(-2.4, 2.4, NUM_DIZITIZED)),
            np.digitize(cart_v, bins=self.bins(-3.0, 3.0, NUM_DIZITIZED)),
            np.digitize(pole_angle, bins=self.bins(-0.5, 0.5, NUM_DIZITIZED)),
            np.digitize(pole_v, bins=self.bins(-2.0, 2.0, NUM_DIZITIZED))
        ]
        return sum([x * (NUM_DIZITIZED**i) for i, x in enumerate(digitized)])

    def update_Q_table(self, observation, action, reward, observation_next):
        '''Q学习更新Q表'''
        state = self.digitize_state(observation)  # 状态离散化
        state_next = self.digitize_state(observation_next)  # 将下一个状态离散化
        Max_Q_next = max(self.q_table[state_next][:])
        self.q_table[state, action] = self.q_table[state, action] + \
            ETA * (reward + GAMMA * Max_Q_next - self.q_table[state, action])

    def decide_action(self, observation, episode):
        '''根据ε-贪婪法逐渐采用最优动作'''
        state = self.digitize_state(observation)
        epsilon = 0.5 * (1 / (episode + 1))

        if epsilon <= np.random.uniform(0, 1):
            action = np.argmax(self.q_table[state][:])
        else:
            action = np.random.choice(self.num_actions)  # 随机返回0.1动作
        return action

# %% [markdown]
# ### 最后定义Environment类。这一次，如果它连续10次站立195步或更多，说明强化学习成功。我们将再次运行一次以保存成功后的动画。

# %%
class Environment:
    '''执行CartPole的环境类'''

    def __init__(self):
        self.env = gym.make(ENV)  # 设置要执行的任务
        num_states = self.env.observation_space.shape[0]  # 获取任务状态的个数
        num_actions = self.env.action_space.n  # 获取CartPole的动作（向左或向右）数为2
        self.agent = Agent(num_states, num_actions)  # 创建在环境中行动的Agent

    def run(self):
        '''执行'''
        complete_episodes = 0  # 持续195步或者更多的步数
        is_episode_final = False  # 最终试验的标志
        frames = []  # 用于存储视频图像的变量

        for episode in range(NUM_EPISODES):  # 试验的最大重复次数
            observation = self.env.reset()  # 环境初始化

            for step in range(MAX_STEPS):  # 每个回合的循环

                if is_episode_final is True:  # 将最终试验各个时刻的图像添加到帧中
                    frames.append(self.env.render(mode='rgb_array'))

                # 求取动作
                action = self.agent.get_action(observation, episode)

                # 通过执行动作a_t找到s_{t+1},r_{t+1}
                observation_next, _, done, _ = self.env.step(
                    action)  # 不使用regain,info

                # 给予奖励
                if done:  # 如果步数超过200，或者如果倾斜超过某一个角度，则done为true
                    if step < 195:
                        reward = -1  # 如何半途摔倒，给予奖励-1作为惩罚
                        complete_episodes = 0  # 站立超过195步，重置试验次数
                    else:
                        reward = 1  # 一直站立到结束时给予奖励1
                        complete_episodes += 1  # 更新连续记录
                else:
                    reward = 0  # 途中奖励为0

                # 使用step_1的状态observation_next更新Q函数
                self.agent.update_Q_function(
                    observation, action, reward, observation_next)

                # observation更新
                observation = observation_next

                # 结束时的处理
                if done:
                    print('{0} Episode: Finished after {1} time steps'.format(
                        episode, step + 1))
                    break

            if is_episode_final is True:  # 在最后一次试验中保存并绘制动画
                display_frames_as_gif(frames)
                break

            if complete_episodes >= 10:  # 如果连续成功10次，绘制下一次试验作为最终试验
                print('10回合连续成功')
                is_episode_final = True

# %%
# main
cartpole_env = Environment()
cartpole_env.run()
# Out:
# 0 Episode: Finished after 11 time steps
# 1 Episode: Finished after 13 time steps
# 2 Episode: Finished after 18 time steps
# 3 Episode: Finished after 111 time steps
# 4 Episode: Finished after 66 time steps
# 5 Episode: Finished after 56 time steps
# 6 Episode: Finished after 32 time steps
# 7 Episode: Finished after 51 time steps
# 8 Episode: Finished after 100 time steps
# 9 Episode: Finished after 20 time steps
# 10 Episode: Finished after 27 time steps
# 11 Episode: Finished after 13 time steps
# 12 Episode: Finished after 30 time steps
# 13 Episode: Finished after 20 time steps
# 14 Episode: Finished after 13 time steps
# 15 Episode: Finished after 15 time steps
# 16 Episode: Finished after 11 time steps
# 17 Episode: Finished after 19 time steps
# 18 Episode: Finished after 12 time steps
# 19 Episode: Finished after 70 time steps
# 20 Episode: Finished after 19 time steps
# 21 Episode: Finished after 18 time steps
# 22 Episode: Finished after 194 time steps
# 23 Episode: Finished after 178 time steps
# 24 Episode: Finished after 96 time steps
# 25 Episode: Finished after 75 time steps
# 26 Episode: Finished after 68 time steps
# 27 Episode: Finished after 24 time steps
# 28 Episode: Finished after 50 time steps
# 29 Episode: Finished after 19 time steps
# 30 Episode: Finished after 16 time steps
# 31 Episode: Finished after 32 time steps
# 32 Episode: Finished after 20 time steps
# 33 Episode: Finished after 109 time steps
# 34 Episode: Finished after 53 time steps
# 35 Episode: Finished after 43 time steps
# 36 Episode: Finished after 172 time steps
# 37 Episode: Finished after 33 time steps
# 38 Episode: Finished after 14 time steps
# 39 Episode: Finished after 174 time steps
# 40 Episode: Finished after 138 time steps
# 41 Episode: Finished after 48 time steps
# 42 Episode: Finished after 12 time steps
# 43 Episode: Finished after 25 time steps
# 44 Episode: Finished after 22 time steps
# 45 Episode: Finished after 85 time steps
# 46 Episode: Finished after 37 time steps
# 47 Episode: Finished after 200 time steps
# 48 Episode: Finished after 45 time steps
# 49 Episode: Finished after 99 time steps
# 50 Episode: Finished after 49 time steps
# 51 Episode: Finished after 33 time steps
# 52 Episode: Finished after 23 time steps
# 53 Episode: Finished after 161 time steps
# 54 Episode: Finished after 21 time steps
# 55 Episode: Finished after 19 time steps
# 56 Episode: Finished after 160 time steps
# 57 Episode: Finished after 114 time steps
# 58 Episode: Finished after 18 time steps
# 59 Episode: Finished after 9 time steps
# 60 Episode: Finished after 34 time steps
# 61 Episode: Finished after 10 time steps
# 62 Episode: Finished after 15 time steps
# 63 Episode: Finished after 44 time steps
# 64 Episode: Finished after 10 time steps
# 65 Episode: Finished after 62 time steps
# 66 Episode: Finished after 32 time steps
# 67 Episode: Finished after 10 time steps
# 68 Episode: Finished after 12 time steps
# 69 Episode: Finished after 29 time steps
# 70 Episode: Finished after 33 time steps
# 71 Episode: Finished after 90 time steps
# 72 Episode: Finished after 38 time steps
# 73 Episode: Finished after 150 time steps
# 74 Episode: Finished after 41 time steps
# 75 Episode: Finished after 94 time steps
# 76 Episode: Finished after 29 time steps
# 77 Episode: Finished after 18 time steps
# 78 Episode: Finished after 95 time steps
# 79 Episode: Finished after 14 time steps
# 80 Episode: Finished after 9 time steps
# 81 Episode: Finished after 171 time steps
# 82 Episode: Finished after 43 time steps
# 83 Episode: Finished after 152 time steps
# 84 Episode: Finished after 89 time steps
# 85 Episode: Finished after 151 time steps
# 86 Episode: Finished after 113 time steps
# 87 Episode: Finished after 200 time steps
# 88 Episode: Finished after 46 time steps
# 89 Episode: Finished after 200 time steps
# 90 Episode: Finished after 20 time steps
# 91 Episode: Finished after 36 time steps
# 92 Episode: Finished after 105 time steps
# 93 Episode: Finished after 147 time steps
# 94 Episode: Finished after 52 time steps
# 95 Episode: Finished after 24 time steps
# 96 Episode: Finished after 10 time steps
# 97 Episode: Finished after 38 time steps
# 98 Episode: Finished after 34 time steps
# 99 Episode: Finished after 89 time steps
# 100 Episode: Finished after 158 time steps
# 101 Episode: Finished after 23 time steps
# 102 Episode: Finished after 107 time steps
# 103 Episode: Finished after 65 time steps
# 104 Episode: Finished after 109 time steps
# 105 Episode: Finished after 113 time steps
# 106 Episode: Finished after 127 time steps
# 107 Episode: Finished after 19 time steps
# 108 Episode: Finished after 67 time steps
# 109 Episode: Finished after 85 time steps
# 110 Episode: Finished after 193 time steps
# 111 Episode: Finished after 140 time steps
# 112 Episode: Finished after 200 time steps
# 113 Episode: Finished after 126 time steps
# 114 Episode: Finished after 132 time steps
# 115 Episode: Finished after 92 time steps
# 116 Episode: Finished after 194 time steps
# 117 Episode: Finished after 33 time steps
# 118 Episode: Finished after 117 time steps
# 119 Episode: Finished after 60 time steps
# 120 Episode: Finished after 192 time steps
# 121 Episode: Finished after 54 time steps
# 122 Episode: Finished after 46 time steps
# 123 Episode: Finished after 130 time steps
# 124 Episode: Finished after 24 time steps
# 125 Episode: Finished after 11 time steps
# 126 Episode: Finished after 69 time steps
# 127 Episode: Finished after 61 time steps
# 128 Episode: Finished after 39 time steps
# 129 Episode: Finished after 67 time steps
# 130 Episode: Finished after 105 time steps
# 131 Episode: Finished after 81 time steps
# 132 Episode: Finished after 131 time steps
# 133 Episode: Finished after 157 time steps
# 134 Episode: Finished after 194 time steps
# 135 Episode: Finished after 166 time steps
# 136 Episode: Finished after 134 time steps
# 137 Episode: Finished after 186 time steps
# 138 Episode: Finished after 27 time steps
# 139 Episode: Finished after 200 time steps
# 140 Episode: Finished after 162 time steps
# 141 Episode: Finished after 200 time steps
# 142 Episode: Finished after 200 time steps
# 143 Episode: Finished after 200 time steps
# 144 Episode: Finished after 148 time steps
# 145 Episode: Finished after 160 time steps
# 146 Episode: Finished after 72 time steps
# 147 Episode: Finished after 200 time steps
# 148 Episode: Finished after 200 time steps
# 149 Episode: Finished after 200 time steps
# 150 Episode: Finished after 163 time steps
# 151 Episode: Finished after 200 time steps
# 152 Episode: Finished after 163 time steps
# 153 Episode: Finished after 112 time steps
# 154 Episode: Finished after 147 time steps
# 155 Episode: Finished after 200 time steps
# 156 Episode: Finished after 183 time steps
# 157 Episode: Finished after 200 time steps
# 158 Episode: Finished after 170 time steps
# 159 Episode: Finished after 200 time steps
# 160 Episode: Finished after 200 time steps
# 161 Episode: Finished after 150 time steps
# 162 Episode: Finished after 200 time steps
# 163 Episode: Finished after 137 time steps
# 164 Episode: Finished after 95 time steps
# 165 Episode: Finished after 150 time steps
# 166 Episode: Finished after 110 time steps
# 167 Episode: Finished after 136 time steps
# 168 Episode: Finished after 143 time steps
# 169 Episode: Finished after 70 time steps
# 170 Episode: Finished after 113 time steps
# 171 Episode: Finished after 182 time steps
# 172 Episode: Finished after 200 time steps
# 173 Episode: Finished after 131 time steps
# 174 Episode: Finished after 200 time steps
# 175 Episode: Finished after 200 time steps
# 176 Episode: Finished after 191 time steps
# 177 Episode: Finished after 10 time steps
# 178 Episode: Finished after 187 time steps
# 179 Episode: Finished after 133 time steps
# 180 Episode: Finished after 200 time steps
# 181 Episode: Finished after 167 time steps
# 182 Episode: Finished after 196 time steps
# 183 Episode: Finished after 200 time steps
# 184 Episode: Finished after 164 time steps
# 185 Episode: Finished after 200 time steps
# 186 Episode: Finished after 200 time steps
# 187 Episode: Finished after 107 time steps
# 188 Episode: Finished after 200 time steps
# 189 Episode: Finished after 200 time steps
# 190 Episode: Finished after 200 time steps
# 191 Episode: Finished after 164 time steps
# 192 Episode: Finished after 200 time steps
# 193 Episode: Finished after 200 time steps
# 194 Episode: Finished after 200 time steps
# 195 Episode: Finished after 200 time steps
# 196 Episode: Finished after 200 time steps
# 197 Episode: Finished after 200 time steps
# 198 Episode: Finished after 200 time steps
# 199 Episode: Finished after 200 time steps
# 200 Episode: Finished after 200 time steps
# 201 Episode: Finished after 200 time steps
# 10回合连续成功
# 202 Episode: Finished after 200 time steps
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-135fd70ab5ea> in <module>
#       1 # main
#       2 cartpole_env = Environment()
# ----> 3 cartpole_env.run()
#
# <ipython-input-6-cc19e6ddc9f9> in run(self)
#      54
#      55             if is_episode_final is True:  # 在最后一次试验中保存并绘制动画
# ---> 56                 display_frames_as_gif(frames)
#      57                 break
#      58
#
# <ipython-input-2-d87f0170759d> in display_frames_as_gif(frames)
#      23
#      24     anim.save('movie_cartpole.mp4')  # 视频b
# ---> 25     display(display_animation(anim, default_mode='loop'))
#      26
#
# F:\Anaconda2019_07\lib\site-packages\JSAnimation\IPython_display.py in display_animation(anim, **kwargs)
#      84     """Display the animation with an IPython HTML object"""
#      85     from IPython.display import HTML
# ---> 86     return HTML(anim_to_html(anim, **kwargs))
#      87
#      88
#
# F:\Anaconda2019_07\lib\site-packages\JSAnimation\IPython_display.py in anim_to_html(anim, fps, embed_frames, default_mode)
#      74             anim.save(f.name,  writer=HTMLWriter(fps=fps,
#      75                                                  embed_frames=embed_frames,
# ---> 76                                                  default_mode=default_mode))
#      77             html = open(f.name).read()
#      78
#
# F:\Anaconda2019_07\lib\site-packages\matplotlib\animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1154                             progress_callback(frame_number, total_frames)
#    1155                             frame_number += 1
# -> 1156                     writer.grab_frame(**savefig_kwargs)
#    1157
#    1158         # Reconnect signal for first draw if necessary
#
# F:\Anaconda2019_07\lib\contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# F:\Anaconda2019_07\lib\site-packages\matplotlib\animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     230             yield self
#     231         finally:
# --> 232             self.finish()
#     233
#     234
#
# F:\Anaconda2019_07\lib\site-packages\matplotlib\animation.py in finish(self)
#     526         # are available to be assembled.
#     527         self._run()
# --> 528         MovieWriter.finish(self)  # Will call clean-up
#     529
#     530     def cleanup(self):
#
# F:\Anaconda2019_07\lib\site-packages\matplotlib\animation.py in finish(self)
#     365     def finish(self):
#     366         '''Finish any processing for writing the movie.'''
# --> 367         self.cleanup()
#     368
#     369     def grab_frame(self, **savefig_kwargs):
#
# F:\Anaconda2019_07\lib\site-packages\matplotlib\animation.py in cleanup(self)
#     529
#     530     def cleanup(self):
# --> 531         MovieWriter.cleanup(self)
#     532
#     533         # Delete temporary files
#
# F:\Anaconda2019_07\lib\site-packages\matplotlib\animation.py in cleanup(self)
#     397         self._frame_sink().close()
#     398         # Use the encoding/errors that universal_newlines would use.
# --> 399         out = TextIOWrapper(BytesIO(out)).read()
#     400         err = TextIOWrapper(BytesIO(err)).read()
#     401         if out:
#
# TypeError: a bytes-like object is required, not 'str'
